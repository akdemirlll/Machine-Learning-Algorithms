# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import matplotlib.pyplot as plt

from matplotlib.cm import ScalarMappable
from matplotlib.colors import Normalize

# %% [markdown]
# ### Defining activation function

# %%
def relu(z):
    """Apply rectified linear unit activation to input array."""
    z = (z > 0) * z
    return z

# %% [markdown]
# #### Relu:
# $$ f(x) = max(0, x)$$
#
# $$ f'(x) = max(0, sign(x))$$
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Sigmoid
#
# ...

# %% [markdown]
# ## Creating a synthetic dataset

# %%
X = np.random.randn(900,2)
beta = np.random.randn(2,1)
y = np.log(X@beta+20) - X[:,1:2]**2 #+ np.random.randn(900,1)

# %% [markdown]
# ## Visualizing Dataset
#
# Dataset is strictly not viable to fit a linear plane.

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 4))
ax[0].scatter(*X.T, c=y.ravel())
ax[0].set_xlabel('$X_1$')
ax[0].set_ylabel('$X_2$')
fig.colorbar(ScalarMappable(norm=Normalize(y.min(), y.max())), ax=ax[0])
ax[0].set_title('y vs X1-X2')
ax[1].set_title('Distribution of target variable: y')
_ = ax[1].hist(y.ravel())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-ea5633635a16> in <module>
#       3 ax[0].set_xlabel('$X_1$')
#       4 ax[0].set_ylabel('$X_2$')
# ----> 5 fig.colorbar(ScalarMappable(norm=Normalize(y.min(), y.max())), ax=ax[0])
#       6 ax[0].set_title('y vs X1-X2')
#       7 ax[1].set_title('Distribution of target variable: y')
#
# c:\users\berk_\appdata\local\programs\python\python37\lib\site-packages\matplotlib\figure.py in colorbar(self, mappable, cax, ax, use_gridspec, **kw)
#    2127                              'panchor']
#    2128         cb_kw = {k: v for k, v in kw.items() if k not in NON_COLORBAR_KEYS}
# -> 2129         cb = cbar.colorbar_factory(cax, mappable, **cb_kw)
#    2130
#    2131         self.sca(current_ax)
#
# c:\users\berk_\appdata\local\programs\python\python37\lib\site-packages\matplotlib\colorbar.py in colorbar_factory(cax, mappable, **kwargs)
#    1564         cb = ColorbarPatch(cax, mappable, **kwargs)
#    1565     else:
# -> 1566         cb = Colorbar(cax, mappable, **kwargs)
#    1567
#    1568     cid = mappable.callbacksSM.connect('changed', cb.on_mappable_changed)
#
# c:\users\berk_\appdata\local\programs\python\python37\lib\site-packages\matplotlib\colorbar.py in __init__(self, ax, mappable, **kw)
#    1070         # Ensure the given mappable's norm has appropriate vmin and vmax set
#    1071         # even if mappable.draw has not yet been called.
# -> 1072         mappable.autoscale_None()
#    1073
#    1074         self.mappable = mappable
#
# c:\users\berk_\appdata\local\programs\python\python37\lib\site-packages\matplotlib\cm.py in autoscale_None(self)
#     372         """
#     373         if self._A is None:
# --> 374             raise TypeError('You must first set_array for mappable')
#     375         self.norm.autoscale_None(self._A)
#     376         self.changed()
#
# TypeError: You must first set_array for mappable

# %% [markdown]
# # Defining helper functions

# %% [markdown]
# ### Batches
#
# A generator object to yield rows of desired batch size from X and y.

# %%
def batches(X, batch_size=32):
    """Generate batches from given np.ndarray.
    
    Array must be at least 2-D.
    """
    if batch_size >= X.shape[0]:
        yield X
    else:
        num_iters = (X.shape[0] // batch_size)
        if not (X.shape[0] % batch_size == 0):
            num_iters += 1
        for i in range(num_iters):
            result = X[i * batch_size : (i + 1) * batch_size]
            yield result

# %% [markdown]
# ## Forward Propagation
#
# Propagate input through network using current parameters. All intermediate layers and $\hat{y}$ is calculated, activations are returned to be used in back-propagation.

# %%
def forward_propagate(X, y, W1, b1, W2, b2, W3, b3):
    """Perform one step of forward propagation."""
    A0 = X
    y0 = y
    m = A0.shape[0]

    Z1 = A0 @ W1 + b1
    A1 = relu(Z1)
    Z2 = A1 @ W2 + b2
    A2 = relu(Z2)
    y_pred = A2 @ W3 + b3
    loss = ((y - y_pred)**2).mean()
    
    return loss, y_pred, A1, A2

# %% [markdown]
# ## Back-propagation
#
# Gradients are propagated back from loss calculated at output using chain rule. Calculated gradients multiplied by a learning rate are used to update parameters to minimize loss.
#
# $$w_i := w_i - \alpha \frac{\partial L}{\partial w_i}$$
# $$b_i := b_i - \alpha \frac{\partial L}{\partial b_i}$$

# %%
def back_propagate(X, y, y_pred, W1, b1, W2, b2, W3, b3, A1, A2, lr):
    """Perform one step of back-propagation.
    
    Calculates gradients and updates parameters.
    """
    A0 = X
    y0 = y
    m = A0.shape[0]
    
    dy_pred = y_pred - y0
    dA2 = dy_pred @ W3.T
    dZ2 = dA2 * (A2 > 0).astype(float)
    dA1 = dZ2 @ W2.T
    dZ1 = dA1 * (A1 > 0).astype(float)
    
    dW3 = 1 / m * (A2.T @ dy_pred)
    db3 = 1 / m * dy_pred.sum(axis=0, keepdims=True)
    dW2 = 1 / m *(A1.T @ dZ2)
    db2 = 1 / m * dZ2.sum(axis=0, keepdims=True)
    dW1 = 1 / m * (A0.T @ dZ1)
    db1 = 1 / m * dZ1.sum(axis=0, keepdims=True)
    
    W1 = W1 - lr * dW1
    b1 = b1 - lr * db1
    W2 = W2 - lr * dW2
    b2 = b2 - lr * db2
    W3 = W3 - lr * dW3
    b3 = b3 - lr * db3
    
    return W1, b1, W2, b2, W3, b3

# %% [markdown]
# ## Train neural network
#
# Perform forward and backward propagation for specified number of epochs.

# %%
def train_network(X, y, W1, b1, W2, b2, W3, b3, batch_size=32, epochs=1000, lr=0.01, verbose=1):
    """Train neural network and return learned parameters and final loss.
    
    Returns:
    -----------
    params : Tuple[W1, b1, W2, b2, W3, b3]
    loss   : float, computed loss for learnt parameters. 
    """
    loss_history = []
    params = W1, b1, W2, b2, W3, b3
    for epoch in range(epochs):
        for rx, ry in zip(batches(X, batch_size=batch_size), batches(y, batch_size=batch_size)):
            loss, y_pred, A1, A2 = forward_propagate(rx, ry, *params)
            params = back_propagate(rx, ry, y_pred, *params, A1, A2, lr)
            loss_history.append(loss)

        if epoch % 100==0 and verbose:
            loss, y_pred, *_ = forward_propagate(X, y, *params)
            print("Loss:", loss)
    loss, *_ = forward_propagate(X, y, *params)
    return params, loss, loss_history

# %% [markdown]
# ## Batch Gradient Descent
#
# Slow but certain steps toward minimum loss.

# %%
W1 = np.random.randn(2,56)
b1 = np.zeros(shape=(1,56))
W2 = np.random.randn(56,24)
b2 = np.zeros(shape=(1,24))
W3 = np.random.randn(24,1)
b3 = np.zeros(shape=(1,1))

params = W1, b1, W2, b2, W3, b3

# %%
# %%time
params, loss, loss_history = train_network(X, y, *params, batch_size=900, epochs=101, lr=0.01)
# Out:
# Loss: 6084.946125080751
# Loss: 0.8762390298855475
# Wall time: 261 ms

# %%
plt.plot(np.clip(loss_history, 0, 100))
plt.title('Batch Gradient Descent')
plt.xlabel('Num batches')
_ = plt.ylabel('Loss')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-00b3dd66e516> in <module>
# ----> 1 plt.plot(np.clip(loss_history, 0, 100))
#       2 plt.title('Batch Gradient Descent')
#       3 plt.xlabel('Num batches')
#       4 _ = plt.ylabel('Loss')
#
# NameError: name 'loss_history' is not defined

# %% [markdown]
# ## Mini-batch Gradient Descent

# %%
W1 = np.random.randn(2,56)
b1 = np.zeros(shape=(1,56))
W2 = np.random.randn(56,24)
b2 = np.zeros(shape=(1,24))
W3 = np.random.randn(24,1)
b3 = np.zeros(shape=(1,1))

params = W1, b1, W2, b2, W3, b3

# %%
# %%time
params, loss, loss_history = train_network(X, y, *params, 32, 101, 0.001)
# Out:
# Loss: 6.145523359616213
# Loss: 0.10818326631549186
# Wall time: 510 ms

# %%
plt.plot(np.clip(loss_history, 0, 100))
plt.title('Mini-Batch Gradient Descent')
plt.xlabel('Num batches')
_ = plt.ylabel('Loss')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-aa26930e6e7d> in <module>
# ----> 1 plt.plot(np.clip(loss_history, 0, 100))
#       2 plt.title('Mini-Batch Gradient Descent')
#       3 plt.xlabel('Num batches')
#       4 _ = plt.ylabel('Loss')
#
# NameError: name 'loss_history' is not defined

# %% [markdown]
# ## Stochastic Gradient Descent

# %%
W1 = np.random.randn(2,56)
b1 = np.zeros(shape=(1,56))
W2 = np.random.randn(56,24)
b2 = np.zeros(shape=(1,24))
W3 = np.random.randn(24,1)
b3 = np.zeros(shape=(1,1))

params = W1, b1, W2, b2, W3, b3

# %%
# %%time
params, loss, loss_history = train_network(X, y, *params, 1, 101, lr=0.001)
# Out:
# Loss: 0.38336087327437307
# Loss: 0.014060191809397537
# Wall time: 9.92 s

# %%
plt.plot(np.clip(loss_history, 0, 100))
plt.title('Stochastic Gradient Descent')
plt.xlabel('Num batches')
_ = plt.ylabel('Loss')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-c994cf1daf77> in <module>
# ----> 1 plt.plot(np.clip(loss_history, 0, 100))
#       2 plt.title('Stochastic Gradient Descent')
#       3 plt.xlabel('Num batches')
#       4 _ = plt.ylabel('Loss')
#
# NameError: name 'loss_history' is not defined

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Creating a synthetic dataset

# %%
import numpy as np

# %%
x_ = np.linspace(-9, 9, 1000)
y_ = np.linspace(-9, 9, 1000)

# %%
def sigmoid(logit):
    logit = np.clip(logit, -1e2, 1e2)
    proba = 1 / (1 + np.exp(-logit))
    return proba

# %%
def odd(p):
    return p / (1 - p)

# %%
def logit(p):
    return np.log(odd(p))

# %%
logit(0.3)
# Out:
# -0.8472978603872036

# %%
sigmoid(-0.8472978603872036)
# Out:
# 0.30000000000000004

# %%
xx, yy = np.meshgrid(x_, y_)

# %%
zz = xx**2 - 2*xx + yy**3 + np.log(xx + 70) - 6 * xx * yy

# %%
def generate_logit(xx, yy):
    logits = (xx**2 - 2*xx + yy**3 + np.log(xx + 70) - 6 * xx * yy) / 3
    return logits

# %%
def generate_probas(xx, yy):
    probas = sigmoid(generate_logit(xx, yy))
    return probas

# %%
plt.contourf(xx, yy, generate_logit(xx, yy), cmap='coolwarm')
plt.colorbar()

# %%
plt.contourf(xx, yy, generate_probas(xx, yy), cmap='coolwarm')

# %% [markdown]
# ## Generating Dataset

# %%
X = np.random.randn(300, 2) * 3

# %%
plt.contourf(xx, yy, generate_probas(xx, yy), cmap='coolwarm')
plt.scatter(*X.T)

# %%
y_probas = generate_probas(*X.T)

# %%
y = np.array(
    [np.random.choice([0, 1], p=[1 - proba, proba])
     for proba in y_probas]
)

# %%
plt.contourf(xx, yy, generate_probas(xx, yy), cmap='coolwarm')
plt.scatter(*X.T, c=y)

# %% [markdown]
# # Forward Propagate

# %%
def forward_propagate_clf(X, y, W1, b1, W2, b2, W3, b3):
    """Perform one step of forward propagation."""
    A0 = X
    y0 = y
    m = A0.shape[0]
    eps = 1e-9

    Z1 = A0 @ W1 + b1
    A1 = sigmoid(Z1)
#     A1 = relu(Z1)
    Z2 = A1 @ W2 + b2
    A2 = sigmoid(Z2)
#     A2 = relu(Z2)
    Z3 = A2 @ W3 + b3
    
    y_pred = sigmoid(Z3)
    loss = (-y * np.log(y_pred + eps) - (1 - y) * np.log(1 - y_pred + eps)).mean()  # binary cross entropy
    
    return loss, y_pred, A1, A2

# %% [markdown]
# ## Back-propagation
#
# Gradients are propagated back from loss calculated at output using chain rule. Calculated gradients multiplied by a learning rate are used to update parameters to minimize loss.
#
# $$w_i := w_i - \alpha \frac{\partial L}{\partial w_i}$$
# $$b_i := b_i - \alpha \frac{\partial L}{\partial b_i}$$

# %%
def back_propagate_clf(X, y, y_pred, W1, b1, W2, b2, W3, b3, A1, A2, lr):
    """Perform one step of back-propagation.
    
    Calculates gradients and updates parameters.
    """
    A0 = X
    y0 = y
    m = A0.shape[0]
    eps = 1e-9
#     loss = (-y * np.log(y_pred) - (1 - y) * np.log(1 - y_pred)).mean()  # binary cross entropy

    dy_pred = (-y * (1 / y_pred + eps)) - ((1 - y) * ((-1) / (1 - y_pred + eps)))
#     dy_pred = y_pred - y0  # lineer regresyonda bu sekildeydi

#     y_pred = sigmoid(Z3)
    
    dZ3 = (y_pred * (1 - y_pred)) * dy_pred
    dA2 = dZ3 @ W3.T
    dZ2 = dA2 * A2 * (1 - A2)
#     dZ2 = dA2 * (A2 > 0).astype(float)
    dA1 = dZ2 @ W2.T
    dZ1 = dA1 * A1 * (1 - A1)
#     dZ1 = dA1 * (A1 > 0).astype(float)
    
    dW3 = 1 / m * (A2.T @ dy_pred)
    db3 = 1 / m * dy_pred.sum(axis=0, keepdims=True)
    dW2 = 1 / m *(A1.T @ dZ2)
    db2 = 1 / m * dZ2.sum(axis=0, keepdims=True)
    dW1 = 1 / m * (A0.T @ dZ1)
    db1 = 1 / m * dZ1.sum(axis=0, keepdims=True)
    
    W1 = W1 - lr * dW1
    b1 = b1 - lr * db1
    W2 = W2 - lr * dW2
    b2 = b2 - lr * db2
    W3 = W3 - lr * dW3
    b3 = b3 - lr * db3
    
    grads = (dW3,
            db3,
            dW2,
            db2,
            dW1,
            db1)
    
    params = (W1, b1, W2, b2, W3, b3)
    
    return params, grads

# %% [markdown]
# ## Train neural network
#
# Perform forward and backward propagation for specified number of epochs.

# %%
def train_network_clf(X, y, W1, b1, W2, b2, W3, b3, batch_size=32, epochs=1000, lr=0.01, verbose=1):
    """Train neural network and return learned parameters and final loss.
    
    Returns:
    -----------
    params : Tuple[W1, b1, W2, b2, W3, b3]
    loss   : float, computed loss for learnt parameters. 
    """
    if y.ndim == 1:
        y = y.reshape(-1, 1)
    
    loss_history = []
    params = W1, b1, W2, b2, W3, b3
    for epoch in range(epochs):
        for rx, ry in zip(batches(X, batch_size=batch_size), batches(y, batch_size=batch_size)):
            
            loss, y_pred, A1, A2 = forward_propagate_clf(rx, ry, *params)
            
            params, grads = back_propagate_clf(rx, ry, y_pred, *params, A1, A2, lr)
            
            loss_history.append(loss)

        if epoch % 100==0 and verbose:
            loss, y_pred, *_ = forward_propagate_clf(X, y, *params)
            print("Loss:", loss)
            

    loss, *_ = forward_propagate_clf(X, y, *params)
    return params, loss, loss_history

# %% [markdown]
# ## Initialize Parameters

# %%
W1 = np.random.randn(2, 17)
b1 = np.zeros((1, 17))
W2 = np.random.randn(17, 17)
b2 = np.zeros((1, 17))
W3 = np.random.randn(17, 1)
b3 = np.zeros((1, 1))

# %%
params, loss, loss_history = train_network_clf(X, y, W1, b1, W2, b2, W3, b3,
                  batch_size=32, epochs=30000, lr=0.001, verbose=1)
# Out:
# Loss: 1.1439029112102448
# Loss: 0.6868714717657015
# Loss: 0.6179358183663125
# Loss: 0.5780797436576264
# Loss: 0.5489913168295946
# Loss: 0.5255341527873953
# Loss: 0.5057272610246126
# Loss: 0.4884383355466624
# Loss: 0.47287991603191754
# Loss: 0.45849942744309613
# Loss: 0.44494262852967875
# Loss: 0.4320218449127614
# Loss: 0.41967022516065383
# Loss: 0.407883456408298
# Loss: 0.3966680740369182
# Loss: 0.3860150829099
# Loss: 0.3758992118138958
# Loss: 0.3662901291171709
# Loss: 0.3571628027126438
# Loss: 0.3485015612934166
# Loss: 0.3402982119234128
# Loss: 0.332547650421048
# Loss: 0.3252455136042293
# Loss: 0.3183911711441967
# Loss: 0.31199533579961314
# Loss: 0.306086420067003
# Loss: 0.30070777488974687
# Loss: 0.2959030604183586
# Loss: 0.2916964595642414
# Loss: 0.28807873752204216
# Loss: 0.2850049649049573
# Loss: 0.2824019006874878
# Loss: 0.2801797918877225
# Loss: 0.2782443787218325
# Loss: 0.2765068464142393
# Loss: 0.2748907978713704
# Loss: 0.27333609533009046
# Loss: 0.27179989618920836
# Loss: 0.27025546419708774
# Loss: 0.2686894043214791
# Loss: 0.26709792668718596
# Loss: 0.26548267760621275
# Loss: 0.2638466221518513
# Loss: 0.2621904171467895
# Loss: 0.260509672177705
# Loss: 0.25879348639868294
# Loss: 0.2570246967117574
# Loss: 0.25518231901560207
# Loss: 0.25324648367538627
# Loss: 0.2512054191283903
# Loss: 0.24906261974196534
# Loss: 0.24684095792976768
# Loss: 0.24458071834403255
# Loss: 0.24233127289044054
# Loss: 0.2401398462415583
# Loss: 0.23804239797982812
# Loss: 0.23605977934130626
# Loss: 0.234198985523334
# Loss: 0.2324572151291746
# Loss: 0.2308263543151211
# Loss: 0.2292965030614231
# Loss: 0.22785817351399365
# Loss: 0.22650336388555237
# Loss: 0.22522588657562476
# Loss: 0.2240212912175105
# Loss: 0.2228866177985664
# Loss: 0.22443563901974362
# Loss: 0.2240310901922062
# Loss: 0.22359919190006064
# Loss: 0.22314498172358935
# Loss: 0.22267272239392227
# Loss: 0.2221860480791784
# Loss: 0.221688083373714
# Loss: 0.22118153699353685
# Loss: 0.22066877280018937
# Loss: 0.22015186098911424
# Loss: 0.2196326122467038
# Loss: 0.21911259749653894
# Loss: 0.2185931555726908
# Loss: 0.21807539080393346
# Loss: 0.2175601620814607
# Loss: 0.2170480645196046
# Loss: 0.21653940430400528
# Loss: 0.21603416674869705
# Loss: 0.21553197694101295
# Loss: 0.21503205162100192
# Loss: 0.21453314009166766
# Loss: 0.2140334509492148
# Loss: 0.21353056021210487
# Loss: 0.21302129496643965
# Loss: 0.2125015849031562
# Loss: 0.21196627213171731
# Loss: 0.21140886761112668
# Loss: 0.21082124101094166
# Loss: 0.21019323118542632
# Loss: 0.20951216977332887
# Loss: 0.2087623270941907
# Loss: 0.2079243299804437
# Loss: 0.20697468801345495

# %%
plt.plot(loss_history)

# %%
loss, y_pred, A1, A2 = forward_propagate_clf(X, y.reshape(-1, 1), *params)

# %%
loss
# Out:
# 0.20589741205785667

# %%
y_pred[:10]
# Out:
# array([[5.00106975e-01],
#        [9.44426462e-01],
#        [9.99994325e-01],
#        [5.35154200e-01],
#        [9.99906763e-01],
#        [9.73536634e-01],
#        [1.88504308e-04],
#        [2.88519895e-03],
#        [9.63889817e-05],
#        [8.14357475e-01]])

# %%
(y == (y_pred.ravel() > 0.5)).mean()
# Out:
# 0.9033333333333333

# %%
XX = np.array([xx.ravel(), yy.ravel()]).T

# %%
XX.shape
# Out:
# (1000000, 2)

# %%
zz = forward_propagate_clf(XX, np.ones((XX.shape[0], 1)), *params)

# %%
ZZ = zz[1].reshape(xx.shape)

# %%
plt.contourf(xx, yy, ZZ, cmap='coolwarm')

# %%
plt.contourf(xx, yy, generate_probas(xx, yy), cmap='coolwarm', alpha=0.5)
plt.contourf(xx, yy, ZZ, alpha=0.5)
plt.scatter(*X.T, c=y)

# %%
A2.shape
# Out:
# (300, 17)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

# %%
A2_pc = pca.fit_transform(A2)

# %%
A2_pc.shape
# Out:
# (300, 2)

# %%
plt.scatter(*A2_pc.T, c=y)

# %%
A1_pc = pca.fit_transform(A1)

# %%
plt.scatter(*A1_pc.T, c=y)

# %% [markdown]
# ## Implementing ANN with Keras

# %%
from keras.models import Sequential
from keras.layers import Dense, LeakyReLU, Softmax, Dropout

# %%
model = Sequential()

model.add(
    Dense(89, input_shape=(2,), activation=None)
)
model.add(LeakyReLU())
model.add(Dropout(0.3))
model.add(Dense(89, activation=None))
model.add(LeakyReLU())
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer="adam",
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(X, y, epochs=100, batch_size=64, verbose=0,
          validation_split=0.1)

# %%
plt.plot(model.history.history['loss'], label='train')
plt.plot(model.history.history['val_loss'], label='test')
plt.legend()

# %%
plt.plot(model.history.history['accuracy'], label='train')
plt.plot(model.history.history['val_accuracy'], label='test')
plt.legend()

# %%
y_pred = model.predict_classes(X)

# %%
(y_pred.ravel() == y).mean()
# Out:
# 0.9033333333333333
