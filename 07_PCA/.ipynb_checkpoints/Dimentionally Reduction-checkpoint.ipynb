# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
population=pd.read_html("https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population")

# %%
population[0]
# Out:
#     Rank      Country(or dependent territory)  Population % of world  \
# 0      1                             China[b]  1404179120        NaN
# 1      2                             India[c]  1366495340        NaN
# 2      3                     United States[d]   330205798        NaN
# 3      4                            Indonesia   269603400        NaN
# 4      5                          Pakistan[e]   220892331        NaN
# ..   ...                                  ...         ...        ...
# 237    –                         Tokelau (NZ)        1400        NaN
# 238  195                     Vatican City[ab]         825        NaN
# 239    –  Cocos (Keeling) Islands (Australia)         555        NaN
# 240    –                Pitcairn Islands (UK)          50        NaN
# 241  NaN                                World  7809315000       100%
#
#             Date         Source(official or UN)
# 0    28 Aug 2020   National population clock[3]
# 1    28 Aug 2020   National population clock[4]
# 2    28 Aug 2020   National population clock[5]
# 3     1 Jul 2020  National annual projection[6]
# 4     1 Jul 2020               UN Projection[2]
# ..           ...                            ...
# 237   1 Jul 2018   National annual estimate[91]
# 238   1 Feb 2019         National estimate[198]
# 239  30 Jun 2019         National estimate[197]
# 240   1 Jan 2020         National estimate[199]
# 241  28 Aug 2020             UN Projection[200]
#
# [242 rows x 6 columns]

# %%
gdp=pd.read_csv("countries of the world.csv")

# %%
gdp
# Out:
#              Country                               Region  Population  \
# 0       Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1           Albania   EASTERN EUROPE                          3581655
# 2           Algeria   NORTHERN AFRICA                        32930091
# 3    American Samoa   OCEANIA                                   57794
# 4           Andorra   WESTERN EUROPE                            71201
# ..               ...                                  ...         ...
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0            647500                       48,0                         0,00
# 1             28748                      124,6                         1,26
# 2           2381740                       13,8                         0,04
# 3               199                      290,4                        58,29
# 4               468                      152,1                         0,00
# ..              ...                        ...                          ...
# 222            5860                      419,9                         0,00
# 223          266000                        1,0                         0,42
# 224          527970                       40,6                         0,36
# 225          752614                       15,3                         0,00
# 226          390580                       31,3                         0,00
#
#     Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 0           23,06                             163,07               700.0
# 1           -4,93                              21,52              4500.0
# 2           -0,39                                 31              6000.0
# 3          -20,71                               9,27              8000.0
# 4             6,6                               4,05             19000.0
# ..            ...                                ...                 ...
# 222          2,98                              19,62               800.0
# 223           NaN                                NaN                 NaN
# 224             0                               61,5               800.0
# 225             0                              88,29               800.0
# 226             0                              67,69              1900.0
#
#     Literacy (%) Phones (per 1000) Arable (%) Crops (%) Other (%) Climate  \
# 0           36,0               3,2      12,13      0,22     87,65       1
# 1           86,5              71,2      21,09      4,42     74,49       3
# 2           70,0              78,1       3,22      0,25     96,53       1
# 3           97,0             259,5         10        15        75       2
# 4          100,0             497,2       2,22         0     97,78       3
# ..           ...               ...        ...       ...       ...     ...
# 222          NaN             145,2       16,9     18,97     64,13       3
# 223          NaN               NaN       0,02         0     99,98       1
# 224         50,2              37,2       2,78      0,24     96,98       1
# 225         80,6               8,2       7,08      0,03      92,9       2
# 226         90,7              26,8       8,32      0,34     91,34       2
#
#     Birthrate Deathrate Agriculture Industry Service
# 0        46,6     20,34        0,38     0,24    0,38
# 1       15,11      5,22       0,232    0,188   0,579
# 2       17,14      4,61       0,101      0,6   0,298
# 3       22,46      3,27         NaN      NaN     NaN
# 4        8,71      6,25         NaN      NaN     NaN
# ..        ...       ...         ...      ...     ...
# 222     31,67      3,92        0,09     0,28    0,63
# 223       NaN       NaN         NaN      NaN     0,4
# 224     42,89       8,3       0,135    0,472   0,393
# 225        41     19,93        0,22     0,29   0,489
# 226     28,01     21,84       0,179    0,243   0,579
#
# [227 rows x 20 columns]

# %%
life=pd.read_html("https://en.wikipedia.org/wiki/List_of_countries_by_past_life_expectancy")

# %%
life=life[2]

# %%
life
# Out:
#     Country ordependent territory          1950–1955          1955–1960  \
#     Country ordependent territory Unnamed: 1_level_1 Unnamed: 2_level_1
# 0                     Afghanistan              28.61              31.12
# 1                         Albania              55.26              59.31
# 2                         Algeria              42.89              45.00
# 3                          Angola              31.39              32.54
# 4             Antigua and Barbuda              58.51              61.03
# ..                            ...                ...                ...
# 197             Western Sahara[7]              35.48              37.40
# 198                         Yemen              34.70              34.70
# 199                        Zambia              42.07              44.13
# 200                      Zimbabwe              48.54              50.59
# 201                         World              46.98              49.33
#
#              1960–1965          1965–1970          1970–1975  \
#     Unnamed: 3_level_1 Unnamed: 4_level_1 Unnamed: 5_level_1
# 0                33.41              35.58              37.83
# 1                64.85              66.24              67.69
# 2                47.29              49.47              51.48
# 3                34.09              36.04              38.05
# 4                63.18              65.05              66.71
# ..                 ...                ...                ...
# 197              39.29              41.23              43.26
# 198              34.71              39.14              43.29
# 199              46.08              47.83              50.16
# 200              52.48              54.13              55.78
# 201              51.17              55.48              58.14
#
#              1975–1980          1980–1985          1985–1990  \
#     Unnamed: 6_level_1 Unnamed: 7_level_1 Unnamed: 8_level_1
# 0                40.39              43.56              47.70
# 1                69.70              70.61              71.98
# 2                54.93              61.57              65.85
# 3                40.00              40.89              41.48
# 4                68.18              69.54              70.75
# ..                 ...                ...                ...
# 197              47.57              51.88              56.20
# 198              48.08              53.03              56.76
# 199              51.47              50.31              46.74
# 200              57.84              60.54              60.18
# 201              60.30              62.06              63.68
#
#              1990–1995           1995–2000           2000–2005  \
#     Unnamed: 9_level_1 Unnamed: 10_level_1 Unnamed: 11_level_1
# 0                51.74               54.17               56.89
# 1                71.73               72.95               74.83
# 2                67.20               69.14               71.50
# 3                42.22               44.73               49.98
# 4                71.88               73.00               74.02
# ..                 ...                 ...                 ...
# 197              58.75               61.27               63.87
# 198              58.52               59.84               61.00
# 199              43.79               43.53               46.86
# 200              54.66               47.35               44.13
# 201              64.59               65.67               67.20
#
#               2005–2010           2010–2015
#     Unnamed: 12_level_1 Unnamed: 13_level_1
# 0                 60.03               62.25
# 1                 75.65               77.66
# 2                 73.88               75.27
# 3                 55.59               60.19
# 4                 75.01               75.82
# ..                  ...                 ...
# 197               66.21               68.41
# 198               62.75               64.17
# 199               52.93               59.73
# 200               48.35               57.64
# 201               69.07               70.79
#
# [202 rows x 14 columns]

# %%
military=pd.read_html("https://en.wikipedia.org/wiki/List_of_countries_by_number_of_military_and_paramilitary_personnel")

# %%
military=military[0]

# %%
gdp.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
# 2         2381740                       13,8                         0,04
# 3             199                      290,4                        58,29
# 4             468                      152,1                         0,00
#
#   Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 0         23,06                             163,07               700.0
# 1         -4,93                              21,52              4500.0
# 2         -0,39                                 31              6000.0
# 3        -20,71                               9,27              8000.0
# 4           6,6                               4,05             19000.0
#
#   Literacy (%) Phones (per 1000) Arable (%) Crops (%) Other (%) Climate  \
# 0         36,0               3,2      12,13      0,22     87,65       1
# 1         86,5              71,2      21,09      4,42     74,49       3
# 2         70,0              78,1       3,22      0,25     96,53       1
# 3         97,0             259,5         10        15        75       2
# 4        100,0             497,2       2,22         0     97,78       3
#
#   Birthrate Deathrate Agriculture Industry Service
# 0      46,6     20,34        0,38     0,24    0,38
# 1     15,11      5,22       0,232    0,188   0,579
# 2     17,14      4,61       0,101      0,6   0,298
# 3     22,46      3,27         NaN      NaN     NaN
# 4      8,71      6,25         NaN      NaN     NaN

# %%
life.head()
# Out:
#   Country ordependent territory          1950–1955          1955–1960  \
#   Country ordependent territory Unnamed: 1_level_1 Unnamed: 2_level_1
# 0                   Afghanistan              28.61              31.12
# 1                       Albania              55.26              59.31
# 2                       Algeria              42.89              45.00
# 3                        Angola              31.39              32.54
# 4           Antigua and Barbuda              58.51              61.03
#
#            1960–1965          1965–1970          1970–1975          1975–1980  \
#   Unnamed: 3_level_1 Unnamed: 4_level_1 Unnamed: 5_level_1 Unnamed: 6_level_1
# 0              33.41              35.58              37.83              40.39
# 1              64.85              66.24              67.69              69.70
# 2              47.29              49.47              51.48              54.93
# 3              34.09              36.04              38.05              40.00
# 4              63.18              65.05              66.71              68.18
#
#            1980–1985          1985–1990          1990–1995  \
#   Unnamed: 7_level_1 Unnamed: 8_level_1 Unnamed: 9_level_1
# 0              43.56              47.70              51.74
# 1              70.61              71.98              71.73
# 2              61.57              65.85              67.20
# 3              40.89              41.48              42.22
# 4              69.54              70.75              71.88
#
#             1995–2000           2000–2005           2005–2010  \
#   Unnamed: 10_level_1 Unnamed: 11_level_1 Unnamed: 12_level_1
# 0               54.17               56.89               60.03
# 1               72.95               74.83               75.65
# 2               69.14               71.50               73.88
# 3               44.73               49.98               55.59
# 4               73.00               74.02               75.01
#
#             2010–2015
#   Unnamed: 13_level_1
# 0               62.25
# 1               77.66
# 2               75.27
# 3               60.19
# 4               75.82

# %%
military.head()
# Out:
#    Flag                 Country  Active military  Reserve military  \
# 0   NaN          Afghanistan[2]           174300                 0
# 1   NaN              Albania[3]             8000                 0
# 2   NaN              Algeria[4]           130000            150000
# 3   NaN               Angola[5]           107000                 0
# 4   NaN  Antigua and Barbuda[6]              180                80
#
#    Paramilitary   Total  Per 1,000 capita(total)  Per 1,000 capita(active)
# 0        148700  323000                      9.2                       5.0
# 1           500    8500                      2.8                       2.6
# 2        187200  467200                     11.2                       3.1
# 3         10000  117000                      3.9                       3.5
# 4             0     260                      2.7                       1.9

# %%
military=military.drop('Flag',axis=1)

# %%
military.head()
# Out:
#                   Country  Active military  Reserve military  Paramilitary  \
# 0          Afghanistan[2]           174300                 0        148700
# 1              Albania[3]             8000                 0           500
# 2              Algeria[4]           130000            150000        187200
# 3               Angola[5]           107000                 0         10000
# 4  Antigua and Barbuda[6]              180                80             0
#
#     Total  Per 1,000 capita(total)  Per 1,000 capita(active)
# 0  323000                      9.2                       5.0
# 1    8500                      2.8                       2.6
# 2  467200                     11.2                       3.1
# 3  117000                      3.9                       3.5
# 4     260                      2.7                       1.9

# %%
import re

# %%
deneme='Afgha nistan[1]'
patern=r"[^A-Za-z\s]"
re.sub(patern,'',deneme)
# Out:
# 'Afgha nistan'

# %%
military['Country']=military['Country'].apply(lambda x:re.sub(patern,'',x))

# %%
military.head()
# Out:
#                Country  Active military  Reserve military  Paramilitary  \
# 0          Afghanistan           174300                 0        148700
# 1              Albania             8000                 0           500
# 2              Algeria           130000            150000        187200
# 3               Angola           107000                 0         10000
# 4  Antigua and Barbuda              180                80             0
#
#     Total  Per 1,000 capita(total)  Per 1,000 capita(active)
# 0  323000                      9.2                       5.0
# 1    8500                      2.8                       2.6
# 2  467200                     11.2                       3.1
# 3  117000                      3.9                       3.5
# 4     260                      2.7                       1.9

# %%
life.columns = life.columns.droplevel()

# %%
life.columns
# Out:
# Index(['Country ordependent territory', 'Unnamed: 1_level_1',
#        'Unnamed: 2_level_1', 'Unnamed: 3_level_1', 'Unnamed: 4_level_1',
#        'Unnamed: 5_level_1', 'Unnamed: 6_level_1', 'Unnamed: 7_level_1',
#        'Unnamed: 8_level_1', 'Unnamed: 9_level_1', 'Unnamed: 10_level_1',
#        'Unnamed: 11_level_1', 'Unnamed: 12_level_1', 'Unnamed: 13_level_1'],
#       dtype='object')

# %%
life=life.rename({"Country ordependent territory":"Country"},axis=1)

# %%
life
# Out:
#                  Country  Unnamed: 1_level_1  Unnamed: 2_level_1  \
# 0            Afghanistan               28.61               31.12
# 1                Albania               55.26               59.31
# 2                Algeria               42.89               45.00
# 3                 Angola               31.39               32.54
# 4    Antigua and Barbuda               58.51               61.03
# ..                   ...                 ...                 ...
# 197    Western Sahara[7]               35.48               37.40
# 198                Yemen               34.70               34.70
# 199               Zambia               42.07               44.13
# 200             Zimbabwe               48.54               50.59
# 201                World               46.98               49.33
#
#      Unnamed: 3_level_1  Unnamed: 4_level_1  Unnamed: 5_level_1  \
# 0                 33.41               35.58               37.83
# 1                 64.85               66.24               67.69
# 2                 47.29               49.47               51.48
# 3                 34.09               36.04               38.05
# 4                 63.18               65.05               66.71
# ..                  ...                 ...                 ...
# 197               39.29               41.23               43.26
# 198               34.71               39.14               43.29
# 199               46.08               47.83               50.16
# 200               52.48               54.13               55.78
# 201               51.17               55.48               58.14
#
#      Unnamed: 6_level_1  Unnamed: 7_level_1  Unnamed: 8_level_1  \
# 0                 40.39               43.56               47.70
# 1                 69.70               70.61               71.98
# 2                 54.93               61.57               65.85
# 3                 40.00               40.89               41.48
# 4                 68.18               69.54               70.75
# ..                  ...                 ...                 ...
# 197               47.57               51.88               56.20
# 198               48.08               53.03               56.76
# 199               51.47               50.31               46.74
# 200               57.84               60.54               60.18
# 201               60.30               62.06               63.68
#
#      Unnamed: 9_level_1  Unnamed: 10_level_1  Unnamed: 11_level_1  \
# 0                 51.74                54.17                56.89
# 1                 71.73                72.95                74.83
# 2                 67.20                69.14                71.50
# 3                 42.22                44.73                49.98
# 4                 71.88                73.00                74.02
# ..                  ...                  ...                  ...
# 197               58.75                61.27                63.87
# 198               58.52                59.84                61.00
# 199               43.79                43.53                46.86
# 200               54.66                47.35                44.13
# 201               64.59                65.67                67.20
#
#      Unnamed: 12_level_1  Unnamed: 13_level_1
# 0                  60.03                62.25
# 1                  75.65                77.66
# 2                  73.88                75.27
# 3                  55.59                60.19
# 4                  75.01                75.82
# ..                   ...                  ...
# 197                66.21                68.41
# 198                62.75                64.17
# 199                52.93                59.73
# 200                48.35                57.64
# 201                69.07                70.79
#
# [202 rows x 14 columns]

# %%
gdp.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
# 2         2381740                       13,8                         0,04
# 3             199                      290,4                        58,29
# 4             468                      152,1                         0,00
#
#   Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 0         23,06                             163,07               700.0
# 1         -4,93                              21,52              4500.0
# 2         -0,39                                 31              6000.0
# 3        -20,71                               9,27              8000.0
# 4           6,6                               4,05             19000.0
#
#   Literacy (%) Phones (per 1000) Arable (%) Crops (%) Other (%) Climate  \
# 0         36,0               3,2      12,13      0,22     87,65       1
# 1         86,5              71,2      21,09      4,42     74,49       3
# 2         70,0              78,1       3,22      0,25     96,53       1
# 3         97,0             259,5         10        15        75       2
# 4        100,0             497,2       2,22         0     97,78       3
#
#   Birthrate Deathrate Agriculture Industry Service
# 0      46,6     20,34        0,38     0,24    0,38
# 1     15,11      5,22       0,232    0,188   0,579
# 2     17,14      4,61       0,101      0,6   0,298
# 3     22,46      3,27         NaN      NaN     NaN
# 4      8,71      6,25         NaN      NaN     NaN

# %%
life['Country']=life['Country'].apply(lambda x:re.sub(patern,'',x))

# %%
gdp['Country']=gdp['Country'].str.strip()

# %%
df=gdp.merge(life).merge(military)

# %%
from sklearn.preprocessing import StandardScaler as ss
from sklearn.decomposition import PCA
from sklearn.impute import SimpleImputer

# %%
df.isna().sum()
# Out:
# Country                                0
# Region                                 0
# Population                             0
# Area (sq. mi.)                         0
# Pop. Density (per sq. mi.)             0
# Coastline (coast/area ratio)           0
# Net migration                          0
# Infant mortality (per 1000 births)     0
# GDP ($ per capita)                     0
# Literacy (%)                           1
# Phones (per 1000)                      1
# Arable (%)                             0
# Crops (%)                              0
# Other (%)                              0
# Climate                               13
# Birthrate                              1
# Deathrate                              1
# Agriculture                            0
# Industry                               0
# Service                                0
# Unnamed: 1_level_1                     0
# Unnamed: 2_level_1                     0
# Unnamed: 3_level_1                     0
# Unnamed: 4_level_1                     0
# Unnamed: 5_level_1                     0
# Unnamed: 6_level_1                     0
# Unnamed: 7_level_1                     0
# Unnamed: 8_level_1                     0
# Unnamed: 9_level_1                     0
# Unnamed: 10_level_1                    0
# Unnamed: 11_level_1                    0
# Unnamed: 12_level_1                    0
# Unnamed: 13_level_1                    0
# Active military                        0
# Reserve military                       0
# Paramilitary                           0
# Total                                  0
# Per 1,000 capita(total)                0
# Per 1,000 capita(active)               0
# dtype: int64

# %%
df
# Out:
#          Country                               Region  Population  \
# 0    Afghanistan        ASIA (EX. NEAR EAST)             31056997
# 1        Albania  EASTERN EUROPE                          3581655
# 2        Algeria  NORTHERN AFRICA                        32930091
# 3         Angola  SUB-SAHARAN AFRICA                     12127071
# 4      Argentina              LATIN AMER. & CARIB        39921833
# ..           ...                                  ...         ...
# 141    Venezuela              LATIN AMER. & CARIB        25730435
# 142      Vietnam        ASIA (EX. NEAR EAST)             84402966
# 143        Yemen  NEAR EAST                              21456188
# 144       Zambia  SUB-SAHARAN AFRICA                     11502010
# 145     Zimbabwe  SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0            647500                       48,0                         0,00
# 1             28748                      124,6                         1,26
# 2           2381740                       13,8                         0,04
# 3           1246700                        9,7                         0,13
# 4           2766890                       14,4                         0,18
# ..              ...                        ...                          ...
# 141          912050                       28,2                         0,31
# 142          329560                      256,1                         1,05
# 143          527970                       40,6                         0,36
# 144          752614                       15,3                         0,00
# 145          390580                       31,3                         0,00
#
#     Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 0           23,06                             163,07               700.0
# 1           -4,93                              21,52              4500.0
# 2           -0,39                                 31              6000.0
# 3               0                             191,19              1900.0
# 4            0,61                              15,18             11200.0
# ..            ...                                ...                 ...
# 141         -0,04                               22,2              4800.0
# 142         -0,45                              25,95              2500.0
# 143             0                               61,5               800.0
# 144             0                              88,29               800.0
# 145             0                              67,69              1900.0
#
#     Literacy (%)  ... Unnamed: 10_level_1 Unnamed: 11_level_1  \
# 0           36,0  ...               54.17               56.89
# 1           86,5  ...               72.95               74.83
# 2           70,0  ...               69.14               71.50
# 3           42,0  ...               44.73               49.98
# 4           97,1  ...               73.33               74.39
# ..           ...  ...                 ...                 ...
# 141         93,4  ...               71.62               72.82
# 142         90,3  ...               72.66               73.81
# 143         50,2  ...               59.84               61.00
# 144         80,6  ...               43.53               46.86
# 145         90,7  ...               47.35               44.13
#
#     Unnamed: 12_level_1 Unnamed: 13_level_1 Active military Reserve military  \
# 0                 60.03               62.25          174300                0
# 1                 75.65               77.66            8000                0
# 2                 73.88               75.27          130000           150000
# 3                 55.59               60.19          107000                0
# 4                 75.18               76.01           74200                0
# ..                  ...                 ...             ...              ...
# 141               73.36               73.95          123000             8000
# 142               74.70               75.56          482000                0
# 143               62.75               64.17           40000                0
# 144               52.93               59.73           15100             3000
# 145               48.35               57.64           29000                0
#
#     Paramilitary    Total Per 1,000 capita(total) Per 1,000 capita(active)
# 0         148700   323000                     9.2                      5.0
# 1            500     8500                     2.8                      2.6
# 2         187200   467200                    11.2                      3.1
# 3          10000   117000                     3.9                      3.5
# 4          31250   105450                     2.4                      1.7
# ..           ...      ...                     ...                      ...
# 141       220000   351000                    11.1                      3.9
# 142      5040000  5522000                    56.9                      5.0
# 143            0    40000                     1.4                      1.4
# 144         1400    19500                     1.2                      0.9
# 145        21800    50800                     3.6                      2.1
#
# [146 rows x 39 columns]

# %%
df.dtypes
# Out:
# Country                                object
# Region                                 object
# Population                              int64
# Area (sq. mi.)                          int64
# Pop. Density (per sq. mi.)             object
# Coastline (coast/area ratio)           object
# Net migration                          object
# Infant mortality (per 1000 births)     object
# GDP ($ per capita)                    float64
# Literacy (%)                           object
# Phones (per 1000)                      object
# Arable (%)                             object
# Crops (%)                              object
# Other (%)                              object
# Climate                                object
# Birthrate                              object
# Deathrate                              object
# Agriculture                            object
# Industry                               object
# Service                                object
# Unnamed: 1_level_1                    float64
# Unnamed: 2_level_1                    float64
# Unnamed: 3_level_1                    float64
# Unnamed: 4_level_1                    float64
# Unnamed: 5_level_1                    float64
# Unnamed: 6_level_1                    float64
# Unnamed: 7_level_1                    float64
# Unnamed: 8_level_1                    float64
# Unnamed: 9_level_1                    float64
# Unnamed: 10_level_1                   float64
# Unnamed: 11_level_1                   float64
# Unnamed: 12_level_1                   float64
# Unnamed: 13_level_1                   float64
# Active military                         int64
# Reserve military                        int64
# Paramilitary                            int64
# Total                                   int64
# Per 1,000 capita(total)               float64
# Per 1,000 capita(active)              float64
# dtype: object

# %%
df.iloc[:,2:]=df.iloc[:,2:].apply(lambda x:pd.to_numeric(x.str.replace(',','.')) if x.dtype=='object'else x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-2366ab94c91c> in <module>
# ----> 1 df.iloc[:,2:]=df.iloc[:,2:].apply(lambda x:pd.to_numeric(x.str.replace(',','.')) if x.dtype=='object'else x)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    6873             kwds=kwds,
#    6874         )
# -> 6875         return op.get_result()
#    6876
#    6877     def applymap(self, func) -> "DataFrame":
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     294             try:
#     295                 result = libreduction.compute_reduction(
# --> 296                     values, self.f, axis=self.axis, dummy=dummy, labels=labels
#     297                 )
#     298             except ValueError as err:
#
# pandas\_libs\reduction.pyx in pandas._libs.reduction.compute_reduction()
#
# pandas\_libs\reduction.pyx in pandas._libs.reduction.Reducer.get_result()
#
# <ipython-input-32-2366ab94c91c> in <lambda>(x)
# ----> 1 df.iloc[:,2:]=df.iloc[:,2:].apply(lambda x:pd.to_numeric(x.str.replace(',','.')) if x.dtype=='object'else x)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5267             or name in self._accessors
#    5268         ):
# -> 5269             return object.__getattribute__(self, name)
#    5270         else:
#    5271             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
#     188         # Replace the property with the accessor object. Inspired by:
#     189         # http://www.pydanny.com/cached-property.html
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\strings.py in __init__(self, data)
#    2037
#    2038     def __init__(self, data):
# -> 2039         self._inferred_dtype = self._validate(data)
#    2040         self._is_categorical = is_categorical_dtype(data)
#    2041         self._is_string = data.dtype.name == "string"
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\strings.py in _validate(data)
#    2094
#    2095         if inferred_dtype not in allowed_types:
# -> 2096             raise AttributeError("Can only use .str accessor with string values!")
#    2097         return inferred_dtype
#    2098
#
# AttributeError: Can only use .str accessor with string values!

# %%
df.dtypes

# %%
x=df.iloc[:,2:]

# %%
scaler=ss()

# %%
imputer=SimpleImputer()

# %%
x=imputer.fit_transform(x)

# %%
X=scaler.fit_transform(x)

# %%
model=PCA(n_components=2)

# %%
X.mean()

# %%
X_pca=model.fit_transform(X)

# %%
plt.figure(figsize=(20,20))
plt.scatter(X_pca[:,0],X_pca[:,1])
for i in range(df.shape[0]):
    plt.text(X_pca[i,0],X_pca[i,1],df['Country'][i])
plt.savefig('country_pca.png', dpi=600)

# %%
model2=PCA()

# %%
X_pca2=model2.fit_transform(X)

# %%
model2.explained_variance_ratio_

# %%
import numpy as np

# %%
np.cumsum(model2.explained_variance_ratio_)

# %%
from sklearn.manifold import TSNE

# %%
modelTSNE= TSNE()

# %%
X_tsne=modelTSNE.fit_transform(X)

# %%
plt.figure(figsize=(20,12))
plt.scatter(X_tsne[:,0],X_tsne[:,1])
for i in range(df.shape[0]):
    plt.text(X_tsne[i,0],X_tsne[i,1],df['Country'][i])
plt.savefig('country.png', dpi=600)

# %%
sigma=np.cov(X.T)

# %%
u,s,v=np.linalg.svd(sigma)

# %%
u_red=u[:,:2]

# %%
u_red.shape

# %%
X_manuel=X@u_red

# %%
X_manuel[0]

# %%
X_pca[0]

# %%
X_manuel_T=u_red.T@X.T

# %%
X_manuel_T[:,0]

# %%
cities = pd.read_html('https://en.wikipedia.org/wiki/Provinces_of_Turkey')[4]

# %%
cities['Name']
